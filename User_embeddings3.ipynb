# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/SPIRS")

# %%
pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 5.5 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 50.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 60.6 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 75.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 70.2 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=1df423c2ef87428e19c7278292f80defb575786e9b0ea23f9fe9eb3d4bc72e09
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 sentence-transformers-2.2.2 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.20.1

# %%
import zipfile
import pandas as pd
from csv import reader
import re
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow

# %%
EMOJI_DESCRIPTION_SCRUB = re.compile(r':(\S+?):')
HASHTAG_BEFORE = re.compile(r'#(\S+)')
FIND_MENTIONS = re.compile(r'@(\S+)')
LEADING_NAMES = re.compile(r'^\s*((?:@\S+\s*)+)')
TAIL_NAMES = re.compile(r'\s*((?:@\S+\s*)+)$')

# %%
from gensim.parsing.preprocessing import remove_stopwords
import emoji

# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 30.6 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=d877d0bf662b96cf185ea6a277ea86d9569d1245f02248892eb74274a0a8d341
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
def process_tweet(s, keep_emoji=True, keep_usernames=False):

  s = s.lower()

  #removing urls, htmls tags, etc
  s = re.sub(r'https\S+', r'', str(s))
  s = re.sub(r'\\n', ' ', s)
  s = re.sub(r'\s', ' ', s)
  s = re.sub(r'<br>', ' ', s)
  s = re.sub(r'&amp;', '&', s)
  s = re.sub(r'&#039;', "'", s)
  s = re.sub(r'&gt;', '>', s)
  s = re.sub(r'&lt;', '<', s)
  s = re.sub(r'\'', "'", s)

  #removing stopwords
  s = remove_stopwords(s)

  #removing emojis
  if keep_emoji:
      s = emoji.demojize(s)
  else:
      emoj = re.compile("["
      u"\U0001F600-\U0001F64F"  # emoticons
      u"\U0001F300-\U0001F5FF"  # symbols & pictographs
      u"\U0001F680-\U0001F6FF"  # transport & map symbols
      u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
      u"\U00002500-\U00002BEF"  # chinese char
      u"\U00002702-\U000027B0"
      u"\U00002702-\U000027B0"
      u"\U000024C2-\U0001F251"
      u"\U0001f926-\U0001f937"
      u"\U00010000-\U0010ffff"
      u"\u2640-\u2642" 
      u"\u2600-\u2B55"
      u"\u200d"
      u"\u23cf"
      u"\u23e9"
      u"\u231a"
      u"\ufe0f"  # dingbats
      u"\u3030"
                    "]+", re.UNICODE)

      s = emoj.sub(r'',s)

 #   s = re.sub(r"\\x[0-9a-z]{2,3,4}", "", s)

  #removing hashtags
  s = re.sub(HASHTAG_BEFORE, r'\1!!', s)


  #removing usernames

  #removing just @sign
  if keep_usernames:
      s = ' '.join(s.split())

      s = re.sub(LEADING_NAMES, r' ', s)
      s = re.sub(TAIL_NAMES, r' ', s)

      s = re.sub(FIND_MENTIONS, r'\1', s)

  #removing username completely
  else:
      s = re.sub(FIND_MENTIONS, r' ', s)
    
  #removing username tags - just in case ??
  s = re.sub(re.compile(r'@(\S+)'), r'@', s)
  user_regex = r".?@.+?( |$)|<@mention>"    
  s = re.sub(user_regex," @user ", s, flags=re.I)
  
  # Just in case -- remove any non-ASCII and unprintable characters, apart from whitespace  
  s = "".join(x for x in s if (x.isspace() or (31 < ord(x) < 127)))
  s = ' '.join(s.split())

  return s

# %%
file = None

with zipfile.ZipFile('spirs_history.zip') as zip:
  file = zip.open('spirs_history/SPIRS-sarcastic-history.txt', mode='r')

#dictionary = {}
tweets_array = []
old_user = None
sentences = []

i = 0
n_user_tweets = 0

for line in file:

  if i > 0000:

    try:
  
      user_id, tweet_id, tweet = re.split(r'\t+', line.decode('utf-8'))

      tweets_array.append([tweet_id, process_tweet(tweet), user_id])

    except:

      print(re.split(r'\t+', line.decode('utf-8')))

  if i == 10000:
    break

  i += 1

# %%
tweets_array
# Out:
# [['1310336957818511362',
#   'yup! resort protective styles protect hair love scissors :loudly_crying_face::loudly_crying_face: lockdown, tempted cut myself!',
#   '51123724'],
#  ['1310336261400473600',
#   ':smiling_face_with_hearts::smiling_face_with_hearts:... conflicted wanting cut vs letting grow :weary_face::weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1310324348729913349',
#   'got lick up! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1310292631721836544',
#   'rt talks loneliness attached bigger person. youre silencing dismissing fe',
#   '51123724'],
#  ['1310291134841794564', 'rt relationship ptsd real', '51123724'],
#  ['1310281047381364736',
#   'rt :speaking_head: endchildfoodpoverty!!',
#   '51123724'],
#  ['1310277415432859648',
#   'mannnn wtf!? :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1310276788367568903', 'rt worse wasted time', '51123724'],
#  ['1310275625878458368',
#   'know sexuality isnt choice. right mind choosing men? :weary_face:',
#   '51123724'],
#  ['1310274699356778496',
#   'feel like going date :thinking_face:... hopefully lil lipton brek air cause :woozy_face::woozy_face::woozy_face::woozy_face:',
#   '51123724'],
#  ['1310247929840635904',
#   'dont laugh man. know heart tho :tired_face: triggering bad :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1310245326310322178',
#   'thing first... cant drop dem face cause cant pick :woozy_face::woozy_face: gih somebody pin number account let snail far face!!',
#   '51123724'],
#  ['1310243683879579649',
#   'im having meltdown close snail mouth :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face: nahhhhhhhhhhhhhh. no.',
#   '51123724'],
#  ['1310243061847515136', '', '51123724'],
#  ['1310241018885922816',
#   'soooo funny :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: do it. murdaaaaaaa',
#   '51123724'],
#  ['1310032908015542273',
#   'lil girl like expect read 8 fucking books tonight :unamused_face: maam...',
#   '51123724'],
#  ['1310008431672266756', 'curve & bold... like blackberry bold', '51123724'],
#  ['1309997930665914370', 'rt yea outside week!', '51123724'],
#  ['1309876670623633409',
#   'rt wishing goat happy birthday today! :goat::tennis::clapping_hands_medium_skin_tone:',
#   '51123724'],
#  ['1309875937580847106',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: man hungry pun foolishness! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1309666225253945346', 'bloop! :upside-down_face:', '51123724'],
#  ['1309663557370490881', 'this. is. hilarious!', '51123724'],
#  ['1309648657264906240', 'love it!', '51123724'],
#  ['1309647585511198720',
#   'ready :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1309642976897961985',
#   "rt wunna orders to-now! d'lish eats! inside eden lodge.",
#   '51123724'],
#  ['1309632505927081984', 'cuhdear :slightly_frowning_face:', '51123724'],
#  ['1309607003367641088', 'murdaaaaaaaaaaa', '51123724'],
#  ['1309486354720579593',
#   "rt daily reminder :sparkles: don't need perfect. need present.",
#   '51123724'],
#  ['1309479466683502592',
#   'rt hope police got video actually perpetrator hope justice served. h',
#   '51123724'],
#  ['1309466940457586689', '', '51123724'],
#  ['1309465602273226753', 'rt merry christmas yall', '51123724'],
#  ['1309465516512284672',
#   'happy birthday luv :partying_face::smiling_face_with_hearts:',
#   '51123724'],
#  ['1309298494226735105', 'you.', '51123724'],
#  ['1309298137564143617', 'poor woman :pensive_face:', '51123724'],
#  ['1309297177026535425', 'mek shed tear :sleepy_face:', '51123724'],
#  ['1309279172834004997',
#   'rt hey guys help help special kids ? rt , thank :blue_heart:',
#   '51123724'],
#  ['1309277776759881730',
#   'wow shite :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: looney tune, lady!',
#   '51123724'],
#  ['1309274972695728128', 'iffffff!', '51123724'],
#  ['1309272981504438272', 'girl look! :unamused_face:', '51123724'],
#  ['1309272611281567744',
#   'rt quick demo showcasing businesses platform.',
#   '51123724'],
#  ['1309272380183846912',
#   'look... ize friends mad, right? body know certifiable! liseann! :tired_face::tired_face:',
#   '51123724'],
#  ['1309236054973702147',
#   'whyyyyyyy mek cackle!?! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1309235712370368515',
#   'da mek holla! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1309215264580472832',
#   'rt stop trying convince people reality isnt simply perspective real',
#   '51123724'],
#  ['1309211504500248577',
#   'rt wrong dating multiple people thats works you. whats wrong keeping information from',
#   '51123724'],
#  ['1309209568640217092',
#   'rt lewis hamilton announced 14 members new diversity commission, including ex-mclaren boss martin whitmarsh hamilt',
#   '51123724'],
#  ['1308905299609296897', 'agreed. sure theyre damn board!!', '51123724'],
#  ['1308902411797491714',
#   'track record, hope literally... :upside-down_face:',
#   '51123724'],
#  ['1308899794086178818',
#   'dem treat bite man rough doh :persevering_face:',
#   '51123724'],
#  ['1308858375917142016',
#   'rt love help other. this! saw thread asked extend opportunity gu',
#   '51123724'],
#  ['1308831631709532161', 'fuckhole madness!', '51123724'],
#  ['1308830767787671552', 'rt deserved :clapping_hands:', '51123724'],
#  ['1308812698822602758',
#   'number yall seek services good therapist. seek help... respectfully.',
#   '51123724'],
#  ['1308804343844548610', 'unlimited quantities...', '51123724'],
#  ['1308802979156373509',
#   'like braids :woman_shrugging_medium_skin_tone: feeling weave.',
#   '51123724'],
#  ['1308798098274164736', 'you?', '51123724'],
#  ['1308797818816147458', 'wappen?', '51123724'],
#  ['1308797081058975744',
#   'braided hair want bundles... mad! lunatic. :woozy_face:',
#   '51123724'],
#  ['1308795689598693381',
#   "rt don't tell lies....how ppl waiting win lotto start life?",
#   '51123724'],
#  ['1308776700571004928',
#   'wa tweet ain mek tiniest bit sense :confused_face::confused_face::confused_face:',
#   '51123724'],
#  ['1308774546984624131', 'da hellllll?!?! :flushed_face:', '51123724'],
#  ['1308746853727588354', 'its you!', '51123724'],
#  ['1308589664098570240', 'no.', '51123724'],
#  ['1308588831415963648', 'carla! nooooooo! :tired_face:', '51123724'],
#  ['1308588243710103553', 'real vexation ya spirit', '51123724'],
#  ['1308587783473201152',
#   'oh... checking! :face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1308586804690530315',
#   'tek owwwwttttttttt :weary_face::weary_face::weary_face::weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1308586416499294208',
#   'literally stupse got pic... men audacity :face_with_rolling_eyes:',
#   '51123724'],
#  ['1308585471845511169',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: frighten?',
#   '51123724'],
#  ['1308526251947307009', '', '51123724'],
#  ['1308521728352583681',
#   'way heat set up, going nocturnal... cant manage!',
#   '51123724'],
#  ['1308518458125148160',
#   "rt realize retweet everybody posts din post smh. i'm virtual assistant yall thread can",
#   '51123724'],
#  ['1308514123748122625', '', '51123724'],
#  ['1308512443581239297',
#   'murdaaaaaaa :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1308512376359129088', 'rt serge mf ibaka....', '51123724'],
#  ['1308511849630101504', 'girllllll... thread :drooling_face:', '51123724'],
#  ['1308468695635812356',
#   'rt sugarless order customer health reasons... aim please.',
#   '51123724'],
#  ['1308462108804341760',
#   'tf gotta speak bout heat??? im bout dieeee :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1308456585178558464',
#   'rt substituted, replaced. dailyspirit!!',
#   '51123724'],
#  ['1308441027787845635',
#   'girl, shut theeeee :clapping_hands_medium_skin_tone: fuck :clapping_hands_medium_skin_tone: :clapping_hands_medium_skin_tone:',
#   '51123724'],
#  ['1308403383716454403',
#   "rt somebody gotta show/tell ain't like lol.... you'll dead gotta check you",
#   '51123724'],
#  ['1308396204917764096', 'rt golden apple available.....', '51123724'],
#  ['1308122594525184001',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1308108357899821059', '', '51123724'],
#  ['1308081179820806147', '', '51123724'],
#  ['1308061808465412096', 'follows think. unfollowed :woozy_face:', '51123724'],
#  ['1308061283447721990',
#   'murdaaaaa :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1308061242414768128',
#   'that! things comment wa cringe af :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1308060040444641283',
#   'knew bout him... funny vibe :slightly_frowning_face:',
#   '51123724'],
#  ['1308050248502308865', 'oh! jah!', '51123724'],
#  ['1308028867702120449',
#   'its good af! :drooling_face::drooling_face::drooling_face:',
#   '51123724'],
#  ['1307856687097876481', 'dont started! :pouting_face:', '51123724'],
#  ['1307850720104849409', 'yip.', '51123724'],
#  ['1307850163340410881',
#   'nahhhh nahhhh... n you! :slightly_frowning_face:',
#   '51123724'],
#  ['1307849592369803267', '', '51123724'],
#  ['1307842585717858304',
#   "rt hi...i'm liseann sell variety natural juices punches. search follow ig :slightly_smiling_face:",
#   '51123724'],
#  ['1307838494992150529',
#   'assure dont! cant avoid :pleading_face::pleading_face:',
#   '51123724'],
#  ['1307786936128614401',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: its fucking twins? its fucking twins!?!? deadddddddddd',
#   '51123724'],
#  ['1307764694627889154',
#   'photo shoot nuff ting come long home :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: real sickening yuh!',
#   '51123724'],
#  ['1307764440109068292', 'yeh, coinsss :weary_face:', '51123724'],
#  ['1307764026148036608',
#   'send dem lemonade dem come coconut punch cherry juice change!! :woozy_face::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1307762655994707971',
#   'bajan cherry-pineapple taste good ic :drooling_face::drooling_face::drooling_face::drooling_face:',
#   '51123724'],
#  ['1307460016870502402',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1307454136426860547', 'entitlement! ughhhh', '51123724'],
#  ['1307430745460404231', 'amen :folded_hands_medium_skin_tone:', '51123724'],
#  ['1307386049610633217',
#   'right now, id it. cant fuck anymore. everybody.',
#   '51123724'],
#  ['1307385032701612039', 'yip.', '51123724'],
#  ['1307384709832474624', 'new season, shite :unamused_face:', '51123724'],
#  ['1307358903823478785', '', '51123724'],
#  ['1307347191758041088',
#   'bold ic tho... know laws :upside-down_face:',
#   '51123724'],
#  ['1307346369296896000', 'quick too!', '51123724'],
#  ['1307345997652258817',
#   'mek da yous cunt!?! slip :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1307301427488972802',
#   ':woozy_face: drunk time so?! maam... settle down.',
#   '51123724'],
#  ['1307143958104076288', '', '51123724'],
#  ['1307143147617742848', 'at. all.', '51123724'],
#  ['1307142695220113408', 'leff', '51123724'],
#  ['1307142540353777667',
#   'gotta pick struggle :woozy_face::woozy_face: cant ugly rude wid',
#   '51123724'],
#  ['1307127268196724736',
#   'iffffffff :weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1307126910271582213',
#   'wicked ic :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1307124792273842176',
#   'somebody dont fuck mitch, swear.... turtle ass mf :face_with_rolling_eyes:',
#   '51123724'],
#  ['1307124210393808899',
#   'feel soooo fackin good right :beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes: vacationnnnnnnnn :flexed_biceps_medium_skin_tone: dont ask cunt bout bank 3 weeks. dont work there.',
#   '51123724'],
#  ['1307121482838007815',
#   'stupse. foolishness... :face_with_rolling_eyes::face_with_rolling_eyes:',
#   '51123724'],
#  ['1307118999780708353', ':slightly_frowning_face:', '51123724'],
#  ['1307116651754725379', 'time so!?', '51123724'],
#  ['1307102821221834759', 'help understand :woozy_face:', '51123724'],
#  ['1307062157595607042',
#   'wan somewhere... its nowhere. im going here, change scenery good :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1307055855695802369', 'wan gooooo :pensive_face:', '51123724'],
#  ['1306972226072256513',
#   'god good :folded_hands_medium_skin_tone:',
#   '51123724'],
#  ['1306970564188205057', 'lucky you!!', '51123724'],
#  ['1306968590445404161',
#   ':face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy: send man... gih sain entertain idiots phone!',
#   '51123724'],
#  ['1306946601357914118',
#   ':woman_facepalming_medium_skin_tone::woman_facepalming_medium_skin_tone::woman_facepalming_medium_skin_tone:',
#   '51123724'],
#  ['1306938116490571776', 'correct.', '51123724'],
#  ['1306934329034014720',
#   'im working home cant. phone, gine dread up!',
#   '51123724'],
#  ['1306934025584603137', 'ize pay gine tell down!!', '51123724'],
#  ['1306933694154899459',
#   'know it! :face_with_rolling_eyes::face_with_rolling_eyes::face_with_rolling_eyes: gine disconnect rh landline.',
#   '51123724'],
#  ['1306933159779590145',
#   'mother church friends bout heated af morning... talking lot uh shite!! :face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth:',
#   '51123724'],
#  ['1306925987335147520', '', '51123724'],
#  ['1306754150210957317', "rt look, she's nice cause jail.", '51123724'],
#  ['1306753825345241088',
#   "rt i'm triggered hitting letting slide!",
#   '51123724'],
#  ['1306752854074458112', '', '51123724'],
#  ['1306751789857898498',
#   'want cbd oil fam :pleading_face:... das all.',
#   '51123724'],
#  ['1306686588211077124',
#   "rt rt need vacation. we're trying something.",
#   '51123724'],
#  ['1306653028309753857',
#   'rt dont miss magic:sparkles::butterfly: re-living wehome!! live moments ready one? :thinking_face: thro!!',
#   '51123724'],
#  ['1306651512114999298',
#   'rt todays card. theres tool treatment mood disorders literally create pleasant events calendar t',
#   '51123724'],
#  ['1306626495092264961',
#   'rt unforeseen expenses piss . hate spending money yc',
#   '51123724'],
#  ['1306582355390468097', 'rt want live life happy :folded_hands:', '51123724'],
#  ['1306581434342219776',
#   'barely 9am fed tuh cunt day alreadyyyyyy!',
#   '51123724'],
#  ['1306400179961188353',
#   'mosquitoes dont cut out!?!? :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face: gawblennnnn... galong wunna bed nuh man!',
#   '51123724'],
#  ['1306397829099905024',
#   'shite here! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: hierarchy sins?? wa bible innnnn???? :woman_raising_hand_medium_skin_tone: plz direct me... wrong :woozy_face:',
#   '51123724'],
#  ['1306390002566340608',
#   'aint fucking gospel... !!!! :woozy_face::woozy_face::woozy_face::woozy_face::woozy_face:',
#   '51123724'],
#  ['1306372408631349249',
#   'oh shiteeeeeeee :woozy_face::woozy_face:',
#   '51123724'],
#  ['1306358717055750144',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1306350794120269825', 'skettel!!', '51123724'],
#  ['1306349695233593346', 'yup!!!', '51123724'],
#  ['1306344190205403136',
#   'having ppl drinks :smiling_face_with_heart-eyes::smiling_face_with_heart-eyes: love this!!',
#   '51123724'],
#  ['1306322838853386241', 'needs life!', '51123724'],
#  ['1306313684810166274', 'sick af :face_with_rolling_eyes:', '51123724'],
#  ['1306289702811635719',
#   'blocked kanye time said slavery choice... ahn business wid n foolishness! dont know tweets :woozy_face:',
#   '51123724'],
#  ['1306276361569435648', 'rt customers best....', '51123724'],
#  ['1306263042506752000',
#   'cant work him. clearly mental issues! dem text tho? knowing erratic is? :woman_facepalming_medium_skin_tone::woman_facepalming_medium_skin_tone:',
#   '51123724'],
#  ['1306262581536002051', 'kanye sick af... sad.', '51123724'],
#  ['1306233896942669826', '', '51123724'],
#  ['1306197104424095754', 'ain bout work morning :pleading_face:', '51123724'],
#  ['1306063718392963077',
#   'thread hilarious! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1306062337154129920',
#   'rt hardest changing careers undoing conditioning teaches life exists young',
#   '51123724'],
#  ['1306059866067341316',
#   'na more!?!? :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: love fa real :smiling_face_with_hearts:',
#   '51123724'],
#  ['1306022234545414144',
#   'replies :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1306018024722399233', '', '51123724'],
#  ['1305981357319954432',
#   'rt remain confident this: goodness lord land living. wait lord; strong',
#   '51123724'],
#  ['1305968957082525698',
#   'try n msg :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1305953516037439488',
#   'rt churches prefer weed sex marriage protecting molesters adulterous pastors. hate',
#   '51123724'],
#  ['1305953204639858690',
#   'rt dont think youre asking , asking wrong person',
#   '51123724'],
#  ['1305942707047665665',
#   'thanks :smiling_face_with_smiling_eyes:. knew... read details.',
#   '51123724'],
#  ['1305902447966195713', 'lolol... ort, cool.', '51123724'],
#  ['1305901168057626625',
#   'remember having discussions blp administration mias... dont remember actually discussed tho :woman_facepalming_medium_skin_tone:',
#   '51123724'],
#  ['1305898406926319619', 'same... cause im lost.', '51123724'],
#  ['1305897660084359169',
#   'somebody tell wa mean average bajan please!',
#   '51123724'],
#  ['1305895424658739200', '', '51123724'],
#  ['1305890123524038657',
#   'add lil coconut water... :drooling_face:',
#   '51123724'],
#  ['1305884581091053569', 'red ju-c life :woozy_face:', '51123724'],
#  ['1305687972843532288',
#   'fuckry highest order girl! dont know dem ain jailed human rights violations :face_with_rolling_eyes:',
#   '51123724'],
#  ['1305642725329588229',
#   'rt totally replaceable work. youre replaceable home.home real life. perspective. alw',
#   '51123724'],
#  ['1305640697891098629', '', '51123724'],
#  ['1305552814664548357',
#   'oh dear... angela look like beat anyhow! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1305511647151300615', 'happy birthday sam! :partying_face:', '51123724'],
#  ['1305305921770401792',
#   'rt week 4 year old asking read bedtime stories bajan. paw patrol caing rescue wunna! he',
#   '51123724'],
#  ['1305214863749402624',
#   'thinking going law degree time?! bothering :face_with_steam_from_nose:',
#   '51123724'],
#  ['1305192751382900737', 'agreed. hate dem chunks :pensive_face:', '51123724'],
#  ['1305186706275139585',
#   "rt gentle reminder you're annoyed lewis wearing shirt wear shir",
#   '51123724'],
#  ['1305166687382245377',
#   'rt retweet mom beautiful too:smiling_face_with_heart-eyes::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts:',
#   '51123724'],
#  ['1305139769186365442',
#   'rt lewis hamilton sending message trackside today. (via',
#   '51123724'],
#  ['1305110409028997120', '', '51123724'],
#  ['1304970509038350336',
#   'rt youve cried passed period cramps rt im trynna',
#   '51123724'],
#  ['1304882167751860225',
#   'rt unprovoked man: makes dismissive disrespectful tweets women. men: jus scroll n laugh women tweeting from',
#   '51123724'],
#  ['1304866567843389446', 'right :thinking_face:', '51123724'],
#  ['1304866456111321088',
#   'want notifications gone :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1304865931726917633',
#   'present :woman_raising_hand_medium_skin_tone:',
#   '51123724'],
#  ['1304846590058917888',
#   'ahn know drink water throw :weary_face::weary_face::weary_face::weary_face::weary_face::weary_face: fuck soooo hotttttt, yall?!?!?!?!?!',
#   '51123724'],
#  ['1304508039500886017',
#   'rt know id like biopic on...dominque dawes.',
#   '51123724'],
#  ['1304506204962643969', 'murdaaaaaaaa', '51123724'],
#  ['1304503180647161857', 'rt walking bout pretty nasty ic.', '51123724'],
#  ['1304502860823003139',
#   'breathing good cheating :thinking_face:',
#   '51123724'],
#  ['1304493901676531713', 'got lick upppppppp', '51123724'],
#  ['1304493347780939776',
#   'rt [1] admit cheating, [2] hit fact well, [3] friend that',
#   '51123724'],
#  ['1304492677686341632',
#   'rt niggas caught cheatin :skull::skull::skull:',
#   '51123724'],
#  ['1304492253331812357', 'look! hey!', '51123724'],
#  ['1304492020602490880',
#   'liseaaaaaannnnnnnnn :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1304376435503751168',
#   'rt belongs life come stay. wont force anyone. prioritize w',
#   '51123724'],
#  ['1304255080787521538',
#   'rt somebody soon appear hate men. dont hate men (i do) hate foolishness especially men trot lo',
#   '51123724'],
#  ['1304254407693959168',
#   'dem got hardware store miserable :weary_face::weary_face:',
#   '51123724'],
#  ['1304253213017812992',
#   'holler sa rh harddddd! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1304243836877668352',
#   'rt ya shutting ya eye swiping ya credit card buy food getting bad feels come mail',
#   '51123724'],
#  ['1304243491065782272',
#   'rt people gonna putting survived barbados cvs moving finding survive debt prayer',
#   '51123724'],
#  ['1304240324743696384',
#   'rt gonna come live massy come 2 bags $150 bill. catch',
#   '51123724'],
#  ['1304239978638184448',
#   'rt the young people need children. whats wrong them?! starving gertrude. cant raise family of',
#   '51123724'],
#  ['1304239795409956865',
#   'rt aint need damn immigration. yall need fix high ass cost living young people reproduce',
#   '51123724'],
#  ['1304239723737743366', 'dont kill she, serena!!! :hot_face:', '51123724'],
#  ['1304239152922202113',
#   'rt tennis, nba, nfl, good night sports me.',
#   '51123724'],
#  ['1304200638780395523',
#   'rt soo huge favour :pleading_face::backhand_index_pointing_right_medium_skin_tone::backhand_index_pointing_left_medium_skin_tone:.in midst crazy pandemic quit day job year pursue passion. apprecia',
#   '51123724'],
#  ['1304199592355999745', 'rt rt ya stomach flat', '51123724'],
#  ['1304149099722276866',
#   'das near burst face! wicked!!! :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1304144888242548736',
#   "rt chemistry compatibility 2 different things. don't caught cultivating chemistry, don't t",
#   '51123724'],
#  ['1304144284136935426',
#   'rt vk baths, iceland :Iceland: via: icelandic_explorer',
#   '51123724'],
#  ['1304143179713859586', 'wasnt looking punchline alllll', '51123724'],
#  ['1304142907239288833',
#   'funny af!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1304109364211593217', 'hate! it!', '51123724'],
#  ['1304108812069154818', 'got vex :face_with_steam_from_nose:', '51123724'],
#  ['1304106739923652614',
#   'rt today world suicide prevention day. remember note you...especially loved ones. they',
#   '51123724'],
#  ['1304081412430139393',
#   'cause doooooo... bare foolishness occur daily bout :weary_face::weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1303882418236125184',
#   'rt having experience you. dailyspirit!!',
#   '51123724'],
#  ['1303875235851186177', 'murdaaaaa :woozy_face:', '51123724'],
#  ['1303870060000313344', '', '51123724'],
#  ['1303863463672983553', '', '51123724'],
#  ['1303862910565994497',
#   'come dem sometimes, das wa :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1303858632971423747',
#   'brother laughing bad :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: cheryl aint easy boy!',
#   '51123724'],
#  ['1303857787173306368',
#   'theaccuracy!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303857708962123784',
#   'ah got mudda, fam!!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:dem went bajan mudda academy something!',
#   '51123724'],
#  ['1303857321211310083',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303856307318009861',
#   'rt life way seriously, ive told. believe trait prevented bad d',
#   '51123724'],
#  ['1303855971773689857',
#   'yip! bare tricks :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1303855804748107776',
#   'dont complain tho cause wake kill insects :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1303855465718259715', 'ya mannnn... iz mudda lololol', '51123724'],
#  ['1303855192568459264',
#   'look! ize vex :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: cause sit dey waitttt til somebody come send dem things fa her!',
#   '51123724'],
#  ['1303854601519665152',
#   'mother wait til ya come room sain send ya things fa :unamused_face: bring water fa muh turn da light ya gine out turn kettle teabag cup fa ma',
#   '51123724'],
#  ['1303844089243238402',
#   'condolences :folded_hands_medium_skin_tone:',
#   '51123724'],
#  ['1303841920494587904', 'wa?! :woozy_face:', '51123724'],
#  ['1303836818857754624',
#   'rt 7,777 tweet rt good luck wudeva :sparkles:',
#   '51123724'],
#  ['1303831584030838784',
#   'toes sweet... gine mek change hey girl :relieved_face:',
#   '51123724'],
#  ['1303831209496186881', 'waiting toe nail grow back!!', '51123724'],
#  ['1303829729569579010',
#   'logged out... ahn gone!!! :pouting_face:',
#   '51123724'],
#  ['1303827976178610176',
#   'fault. ize gotta waiting ppl things need :pleading_face:',
#   '51123724'],
#  ['1303827149032509441',
#   'int fuckin day sign work 7??? jesus christ mannnnnnnn :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1303824857717706752', 'rt retweet hot rh.', '51123724'],
#  ['1303815602289737734',
#   'yup :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303793824553205760',
#   'rt lie cv... thats people dont wanna hire me? gotta learn lie? :persevering_face:',
#   '51123724'],
#  ['1303791784074653698',
#   'hilarious!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303753345451122688', 'amen!', '51123724'],
#  ['1303739325906067458',
#   ':partying_face::partying_face::partying_face::partying_face::partying_face::partying_face::partying_face::partying_face:',
#   '51123724'],
#  ['1303738985592827917',
#   'wait! sorta new flavours confuse head :weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1303738854986444801', 'rt', '51123724'],
#  ['1303663188874088449', 'dead.', '51123724'],
#  ['1303504521864380422', 'long finished work gotta study...', '51123724'],
#  ['1303452355128688640',
#   'rt why, soul, downcast? disturbed me? hope god, praise him, savior a',
#   '51123724'],
#  ['1303170820181815296', '', '51123724'],
#  ['1303170011587121158',
#   'waves created bigger boats sink dem :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: titanic song recorder got cut fine :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1303168613042597888',
#   'foolishness like so?? :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303168447078191106', '', '51123724'],
#  ['1303168308334788613',
#   'real sicka heeeee :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303153366952939520',
#   'rt private relationship means knows yall business everybody knows yall together, dont confused.',
#   '51123724'],
#  ['1303152676184653825',
#   'gonna hard cause never... wonder going ppl head dem things like :slightly_frowning_face:',
#   '51123724'],
#  ['1303152051975749632',
#   'yupppp! look like enjoying song :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy: couple flashbacks :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1303151408133427202', 'yeh, saw this. look good ic 78 tho!!', '51123724'],
#  ['1303149192488120322',
#   'rt want work people? no. want entrepreneur? no.',
#   '51123724'],
#  ['1303148697715433472', 'nooooooo', '51123724'],
#  ['1303148292411457537', 'rt wave fedupsy wash me, yes', '51123724'],
#  ['1303148246462857216',
#   'burn :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1303129093878222849',
#   'no. ain exaggerating all. cause thats exactly was! victim blaming... :face_with_rolling_eyes::face_with_rolling_eyes:',
#   '51123724'],
#  ['1303123079649021952',
#   ':loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1303109713576562688',
#   'man wasnt impressed tattoo :woozy_face::woozy_face::woozy_face: glad foolish continue like unchecked.',
#   '51123724'],
#  ['1303109313205080064', 'girl.', '51123724'],
#  ['1303104388366585858', '', '51123724'],
#  ['1303060137918238722', 'please. see.', '51123724'],
#  ['1303059703426101249', '', '51123724'],
#  ['1303058395021348865',
#   'tingggggggggg!!!!! confused :confused_face:',
#   '51123724'],
#  ['1303056915556167682', 'das igrance! :exploding_head:', '51123724'],
#  ['1303056820966129664',
#   'im fucking flabbergasted :flushed_face:',
#   '51123724'],
#  ['1303056713696894977',
#   'bout normalize liking ppl things them, killing ppl fa theirs!',
#   '51123724'],
#  ['1303054748975861760',
#   'wait... ppl trying lend somebody money ask repayment expect killed dont want repay? :woozy_face::woozy_face::woozy_face::woozy_face::woozy_face::woozy_face:',
#   '51123724'],
#  ['1303049292089884674', 'thank kindly', '51123724'],
#  ['1303044281091985411',
#   'rt sister loves music, specifically unbreak heart entire debut album toni braxton. :smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::cat_with_tears_of_joy:',
#   '51123724'],
#  ['1303040351825993728', 'nope. man chest :woozy_face:', '51123724'],
#  ['1303039628153434113', 'got awllllll da way fucked up!!!', '51123724'],
#  ['1303035773734748160',
#   'ill assume youve met yours, willing confirm mothers cousins responsible paternity? were line questioning... :upside-down_face:',
#   '51123724'],
#  ['1303030559384522753', 'yes maam :pensive_face:', '51123724'],
#  ['1303029917513330688',
#   'when feel stressed stay life challenges meant shape you stupse :face_with_rolling_eyes:',
#   '51123724'],
#  ['1303022904771309568',
#   'soooo tempted ask father is... mothers 1st, 2nd 3rd cousin :upside-down_face::unamused_face:',
#   '51123724'],
#  ['1303019798943731712',
#   'rt dear lord, today, bless week ahead me. declare longer labour vain! eat fruits m',
#   '51123724'],
#  ['1303019774469976065',
#   'rt todays mantra: receiving abundantly sharing generously.',
#   '51123724'],
#  ['1302937669064896513', 'thanks :face_blowing_a_kiss:', '51123724'],
#  ['1302937442647932928', ':smiling_face_with_open_hands:', '51123724'],
#  ['1302797911688974341',
#   'hate feeling dread think work morning. edge bed like...',
#   '51123724'],
#  ['1302792185616760833',
#   'rt genre music exudes euphoria soca does!',
#   '51123724'],
#  ['1302765308688633861', 'feed he?!? :flushed_face:', '51123724'],
#  ['1302747210975772676', 'rt thatpart!!', '51123724'],
#  ['1302747139827814406',
#   'rt *keywords tweet : how-you-treat-them. value ( respect) time treat (her) gifts etc. peop',
#   '51123724'],
#  ['1302747104973131778', 'rt women money dont care treat', '51123724'],
#  ['1302707235450167300',
#   'rt dont hurt feelings tryna youre not. dont try pretend emotionally detach g',
#   '51123724'],
#  ['1302707214495481864',
#   'rt people sex issue, sex needs accompanied emotional connnection',
#   '51123724'],
#  ['1302707165510225924',
#   'rt casual sex aint everybody. hell, its people engaging casual sex dont business b',
#   '51123724'],
#  ['1302689999331229697',
#   'rt things 3 years ago trigger fresh healing straightforward',
#   '51123724'],
#  ['1302678126183546887',
#   'correct. lil poison teach valuable lesson.',
#   '51123724'],
#  ['1302673033606422530', 'poison. its way.', '51123724'],
#  ['1302621934472097795',
#   'rt its hard woman, men weak :loudly_crying_face:',
#   '51123724'],
#  ['1302621752615464960',
#   'rt having educated girl opinion aint weak :loudly_crying_face::loudly_crying_face::loudly_crying_face::loudly_crying_face::slightly_smiling_face:',
#   '51123724'],
#  ['1302607740938924034',
#   "rt ''momma'' :loudly_crying_face::smiling_face_with_heart-eyes:",
#   '51123724'],
#  ['1302578430882570240',
#   'dont like :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1302578211679875072',
#   'ahhhh... dont like industrial style lofts! nice :smiling_face_with_heart-eyes: warmer...',
#   '51123724'],
#  ['1302390237440684035', 'gotta ig video tour', '51123724'],
#  ['1302389824779948032', 'now, mel... :worried_face:', '51123724'],
#  ['1302389657842462720',
#   'love it... exposed ductwork :smiling_face_with_hearts:',
#   '51123724'],
#  ['1302389082685952000',
#   ':smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::smiling_face_with_heart-eyes:',
#   '51123724'],
#  ['1302388449648013312',
#   'rt literally dream loft.. :star-struck:',
#   '51123724'],
#  ['1302387896859664384',
#   'rt twitter signal boost this. base (barbados association supported employment) non-profit organi',
#   '51123724'],
#  ['1302367569056354304',
#   'rasshole wunna couldnt bat tournament!?!? stuuuuuuupse.',
#   '51123724'],
#  ['1302366225301938176', 'time!', '51123724'],
#  ['1302353559502061570',
#   'vex big jase!?! :upside-down_face::upside-down_face::upside-down_face:',
#   '51123724'],
#  ['1302341046710472705', 'rt mental health important', '51123724'],
#  ['1302340705642307593',
#   'rt jessica pearson queen corporate drip',
#   '51123724'],
#  ['1302277692843270146',
#   'rt yall stop wasting folks time talking bout lets flow. nah mane its gone',
#   '51123724'],
#  ['1302264269841539072', 'boyyyyy! n rest nuh...', '51123724'],
#  ['1302250752933494786',
#   'yous cant hush up!?! :disappointed_face:',
#   '51123724'],
#  ['1302250016040456192',
#   'rt twitter gaffs & laughs gaff & laugh.',
#   '51123724'],
#  ['1302233445603696641',
#   'ppl dont like soca trusted. its :triangular_flag:',
#   '51123724'],
#  ['1302230770849902597',
#   ':smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts:',
#   '51123724'],
#  ['1302230076038295552',
#   "rt tag friend who'd like play peek-a-boo sweet pup! :dog_face:",
#   '51123724'],
#  ['1302228742178209792',
#   'rt hes racist, yes. hes xenophobic hates women corrupt, yes. gets stupid',
#   '51123724'],
#  ['1302075770509164547',
#   'rt seriously way treated cause u sit wonder....what wrong me?......it messes your',
#   '51123724'],
#  ['1302064967429091329',
#   'dem dont know wa say! shut dem ass mout stop mekkin dem self sound foolish :upside-down_face:',
#   '51123724'],
#  ['1302064417790734338',
#   'irks life outta me!!! how bade? ya bade ya fingernails now!? :woozy_face:',
#   '51123724'],
#  ['1302057679620321282',
#   'fall out, ain apologising... meant said.',
#   '51123724'],
#  ['1302055825016532993', 'rt im sorry didnt listen told you.', '51123724'],
#  ['1302055799674548229', "rt i'm sorry i'm right. (capricorn)", '51123724'],
#  ['1302055751280734209', 'thread :smiling_face_with_hearts:', '51123724'],
#  ['1302050293392248834',
#   'gotta cici breakkk :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1302044854596370437', 'rt basically...', '51123724'],
#  ['1301966078537592834',
#   "rt share young adults living parents (52% july) historic high. haven't seen numbers",
#   '51123724'],
#  ['1301961091417862145',
#   'lavender oil water spray bottle :smirking_face:',
#   '51123724'],
#  ['1301952732438331393',
#   "rt want know... there's time place you! time coming perfect place receiv",
#   '51123724'],
#  ['1301938884792680450', 'rt yooo.... rts tour cbc??', '51123724'],
#  ['1301898578407895041',
#   'rt thing bout me, gonna drink tea:smiling_face:',
#   '51123724'],
#  ['1301897857788764172', 'happy birthday sheldon', '51123724'],
#  ['1301665471465426944',
#   'rt learn accept things decide want apart not...ppl want',
#   '51123724'],
#  ['1301664374780821504',
#   'yessssssss!! loved :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1301637241517858820', ':weary_face::weary_face::weary_face:', '51123724'],
#  ['1301631888965210113', 'working :upside-down_face:', '51123724'],
#  ['1301606528089288706',
#   'read ass, mel. cause like hit wid wuk stick :loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#   '51123724'],
#  ['1301606228255277057', 'loud for!? :weary_face::weary_face:', '51123724'],
#  ['1301604991824785416',
#   'mek cackle?! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1301604129970757632',
#   'hr dont believe ppl taking dem sick days ya :woozy_face:',
#   '51123724'],
#  ['1301584825275604993',
#   'rt guyana:!! guyana created history tuesday, sept. 1st, election countrys indigenous deputy spea',
#   '51123724'],
#  ['1301544596011446273', 'person lives alone??', '51123724'],
#  ['1301544307179106304',
#   'rt intuitive instinctive feeling, follow it, universe moving receive wha',
#   '51123724'],
#  ['1301544281753227265',
#   'rt things thought break things stronger. dailyspirit!!',
#   '51123724'],
#  ['1301543994170712065',
#   "rt who's opinion listening to? elevationchurch!! stevenfurtick!! opinions!!",
#   '51123724'],
#  ['1301543041048739840',
#   'rt sports therapy specifically concerned prevention injury rehabilitation optimum levels fun',
#   '51123724'],
#  ['1301535401656627203', 'rt wait vacation', '51123724'],
#  ['1301527255655632897', 'rt likes 20 packs eclipse original ?', '51123724'],
#  ['1301526885847969793',
#   "rt heard? new eclipse dippers here! can't wait debate elite :eyes: eclipsedippers!! h",
#   '51123724'],
#  ['1301320731100405765', 'yes.', '51123724'],
#  ['1301320240693940226',
#   'rt aries, virgo & capricorn intimidating cause know want scram',
#   '51123724'],
#  ['1301317751030636544',
#   'murdaaaaaa :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1301314854310096898', 'rt :) no. thanks though.', '51123724'],
#  ['1301314840477208577',
#   'rt read article ? :eyes: thanks additional list though.',
#   '51123724'],
#  ['1301275625534222343',
#   'want spam calls stop! yesterday ive receiving calls colombia area code... different number time. ive blocked number called. annoying!',
#   '51123724'],
#  ['1301259480991232003', 'tired blocking numbers!', '51123724'],
#  ['1301258853292666885',
#   'gave number colombia??? cause foolishness now!',
#   '51123724'],
#  ['1301100581763846145',
#   'woman serious?? 6am appropriate time cursing ppl?!?! :face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth:',
#   '51123724'],
#  ['1300983142774341632',
#   ':loudly_crying_face::loudly_crying_face::smiling_face_with_hearts:',
#   '51123724'],
#  ['1300982614510141442',
#   ':smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts::smiling_face_with_hearts:',
#   '51123724'],
#  ['1300935426925047808',
#   'rt got aaliyah, fightin crowd: need resolution need resolution muc',
#   '51123724'],
#  ['1300934208043483136',
#   'rt its giving whew chile ghetto cause look fatigue walk i-',
#   '51123724'],
#  ['1300929973465812992',
#   'rasshole body colombia calling cunt phone time so????',
#   '51123724'],
#  ['1300926829172269061',
#   'agreed! throw ass outtttttt soda! (a beastly cold lil bit ice slushy :drooling_face::drooling_face:)',
#   '51123724'],
#  ['1300924914313105411',
#   'wudda fuck fa coke :face_with_steam_from_nose:',
#   '51123724'],
#  ['1300924204611702786', 'know! dem ain easy boy...', '51123724'],
#  ['1300923703635701761',
#   'lie??? :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1300896766439587840', 'rt great t20 viewing engvpak!!', '51123724'],
#  ['1300881009341353985', '', '51123724'],
#  ['1300877354034696192',
#   'rt opening sequence wehome!! virtual concert. happy overwhelming',
#   '51123724'],
#  ['1300875871398572033',
#   'sick ya :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1300867922701815810', 'nope. me.', '51123724'],
#  ['1300860621542612993',
#   'need rest. time rest attempt to-do list :smiling_face_with_open_hands:',
#   '51123724'],
#  ['1300833986168729602',
#   'cant imagine mouth feel like :woozy_face::woozy_face:',
#   '51123724'],
#  ['1300821527336812544', 'confused :confused_face:', '51123724'],
#  ['1300818676808065025',
#   'rt absence impactful presence. dailyspirit!!',
#   '51123724'],
#  ['1300818444129120261',
#   'rt work & career horoscope sep 1, 2020 => read rest at: do? capricorn!! capric!!',
#   '51123724'],
#  ['1300818143930191872',
#   'rt wishing everybody abundance insight new month! remember:',
#   '51123724'],
#  ['1300634660079382528',
#   'dem norwoods annoying ic!!! :face_with_rolling_eyes::face_with_rolling_eyes::face_with_rolling_eyes:',
#   '51123724'],
#  ['1300611482149769217',
#   'hate fa sayin so! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1300611097947496449',
#   'eye. am. hollering!!!!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1300610101997432832',
#   'nearly hing pun dese chips :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1300607620517158913',
#   'sickening ic :weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1300604737449062402', 'rt monica brandy right now.', '51123724'],
#  ['1300599825025597445', 'foolishness :unamused_face:', '51123724'],
#  ['1300595934716481538', 'rt :smiling_face_with_heart-eyes:', '51123724'],
#  ['1300584607201591298',
#   'rt maybe stereotype lesbians moving quickly exists simply men dont',
#   '51123724'],
#  ['1300584521402912768', 'you!', '51123724'],
#  ['1300568212623577096',
#   'rt love vulnerability hand hand. truly love loved, open ways sca',
#   '51123724'],
#  ['1300508091360870402', 'rt soon', '51123724'],
#  ['1300484970218127362', 'rt peace coming from?', '51123724'],
#  ['1300258827921694720',
#   "rt working time doesn't hero. fact, it's likely efficient higher risk burn",
#   '51123724'],
# ...
#   'child ya bear pain for??? ahn want sorry ting.',
#   '51123724'],
#  ['1289031898442891264', 'yes... live here??', '51123724'],
#  ['1289031662303617024', 'cant sleep :pleading_face:', '51123724'],
#  ['1289031567873134592',
#   'hands rated e everybody. instance jail... drive dodds!',
#   '51123724'],
#  ['1289029387183165440',
#   'saying lord bless children, im gonna introduce school orientation... hi, im charise... xyzs mother fight kids!',
#   '51123724'],
#  ['1289028581385998337',
#   'rt hard harsh. wake jenkins yc. send people mad',
#   '51123724'],
#  ['1288997320479117313', 'murdaaaaaaa', '51123724'],
#  ['1288993196257746944',
#   'herman fuckin idiot :face_with_rolling_eyes::face_with_rolling_eyes:',
#   '51123724'],
#  ['1288990306176839687',
#   'yip! cause holla :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288990117668048897',
#   'da suit he! shudda worn damn mask :weary_face:',
#   '51123724'],
#  ['1288989907491393536', '', '51123724'],
#  ['1288989685788925952', 'saw this you? tweet??', '51123724'],
#  ['1288947141214449665', '', '51123724'],
#  ['1288909112772890624', 'ohhhhhh good! :pleading_face:', '51123724'],
#  ['1288901757926617088',
#   'sick! ic! :weary_face::weary_face::weary_face:',
#   '51123724'],
#  ['1288897452259581953',
#   'assssssss!? :flushed_face::flushed_face:',
#   '51123724'],
#  ['1288892478784000001',
#   'rt wish yall stop discouraging people choose pursue education.... people need damn degree & school.',
#   '51123724'],
#  ['1288880603983753218',
#   'rt usually hardest needed most. dailyspirit!!',
#   '51123724'],
#  ['1288867714887487489',
#   'rt talk ambition reminiscent making case vp months ago. said',
#   '51123724'],
#  ['1288807671047626753', 'hate it!!', '51123724'],
#  ['1288804219328372737',
#   'yet... favourite pastime :unamused_face:',
#   '51123724'],
#  ['1288801906706481152',
#   'fackin glue gun... stupse. :face_with_rolling_eyes:',
#   '51123724'],
#  ['1288795371490205698',
#   'dem better pray live age! :upside-down_face:',
#   '51123724'],
#  ['1288790364485230597',
#   'oh christ :face_with_hand_over_mouth::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288643148135227395',
#   'sick :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288627952087859209',
#   'rt restructure tourism industry, economist urges -',
#   '51123724'],
#  ['1288624607998676992',
#   'maam, apologize. lot going today. whatsapp :folded_hands_medium_skin_tone:',
#   '51123724'],
#  ['1288624070670659585',
#   'laying darkness eating pringles... :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1288623823542198274', '', '51123724'],
#  ['1288623402325094419', '', '51123724'],
#  ['1288621361393471492', 'oh!', '51123724'],
#  ['1288620508217577474', '', '51123724'],
#  ['1288619923078557699',
#   'bade cold water torchlight :loudly_crying_face::loudly_crying_face: wasnt bad.',
#   '51123724'],
#  ['1288618016561930242', 'hate laugh :weary_face::weary_face:', '51123724'],
#  ['1288617102442733578',
#   'like somebody help understand... stupse. working!',
#   '51123724'],
#  ['1288599786556395523',
#   'resident taste tester here... wappen ain hear bout this? :eyes:',
#   '51123724'],
#  ['1288593710918389760',
#   'right response situation tbh tho... :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1288591555473952768', ':unamused_face:', '51123724'],
#  ['1288565812408856580',
#   'rt possibly best thing ive seen. cant. stop. laughing...',
#   '51123724'],
#  ['1288564946809356288',
#   'rt tell person thinks way behave. dailyspirit!!',
#   '51123724'],
#  ['1288538116375142401',
#   'play stupid games... :smirking_face::smirking_face:',
#   '51123724'],
#  ['1288530071020593154', '', '51123724'],
#  ['1288528640452567042', ':woman_facepalming_medium_skin_tone:', '51123724'],
#  ['1288528532482793474', 'maam... :unamused_face:', '51123724'],
#  ['1288526870099697664',
#   "rt it's you're with, dynamic them. that's big takeaway landmark study explores mak",
#   '51123724'],
#  ['1288499241401364486',
#   'rt time pop bottles:bottle_with_popping_cork::bottle_with_popping_cork: following classic shows coming (us) moesha - aug 1 game s1-3 - aug 15',
#   '51123724'],
#  ['1288497842882043907', '', '51123724'],
#  ['1288494113961185280', 'rt got sporty ppl', '51123724'],
#  ['1288492447119691776',
#   'wunna know women das condone sorta thing??',
#   '51123724'],
#  ['1288489892897591297',
#   'rt life blessings everybody morning! focus things wanna increase ignore',
#   '51123724'],
#  ['1288489610839044097', 'lord knows havent reproduced yet...', '51123724'],
#  ['1288486299545018375',
#   'want ppl understand im home, im fucking working! door open isnt invitation stop talk... kindly stop calling minutes.:double_exclamation_mark::double_exclamation_mark::double_exclamation_mark::double_exclamation_mark::double_exclamation_mark:',
#   '51123724'],
#  ['1288425095883567106',
#   'know wid wunna... applause moisturizer. :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288423103098433538',
#   ':woozy_face::woozy_face::woozy_face: basic skin care routine cleanse, tone, moisturize tho... so? well... hes moisturizer... :clapping_hands_medium_skin_tone::clapping_hands_medium_skin_tone:',
#   '51123724'],
#  ['1288421719418470401', 'help understand... :confused_face:', '51123724'],
#  ['1288310517099044864',
#   'rt men, dating advice: set standard dont date find sexual compatibility get do jealou',
#   '51123724'],
#  ['1288309436155650052', ':unamused_face:', '51123724'],
#  ['1288305116957769730', 'nope. lemme tomorrow morning.', '51123724'],
#  ['1288303223326101506', 'christ! :flushed_face:', '51123724'],
#  ['1288277809446690816',
#   'murdaaaaaa :face_with_tears_of_joy::face_with_tears_of_joy:',
#   '51123724'],
#  ['1288276798967603206',
#   'rt tino sweet girl situation lesson inside it: state want person',
#   '51123724'],
#  ['1288275864816439297',
#   'guess :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1288274842173800449',
#   'lot uh wunna tweet like ppl dont know wunna real life... concerning (no, :upside-down_face:)',
#   '51123724'],
#  ['1288266038178701312',
#   'night wunna pun foolishness... :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288265505950838785',
#   'das wa got cackling :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1288262027878846465', 'maam', '51123724'],
#  ['1288261511442583557',
#   'lies :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1288259947436834816',
#   'rt know cant handle rejection no stay quiet corner :loudly_crying_face:',
#   '51123724'],
#  ['1288258034502963200',
#   'rt so. tell yall story? grew poor. like poor poor. adult comfortable place financia',
#   '51123724'],
#  ['1288220489635319809', ':woozy_face::woozy_face::woozy_face:', '51123724'],
#  ['1288183167959158784',
#   'rt 84 out!:flexed_biceps_medium-dark_skin_tone:happy birthday greatest batsman :globe_showing_Europe-Africa: seen!:goat: meninmaroon!! check legendary player',
#   '51123724'],
#  ['1288181580746444801',
#   'month, cycle decided introduce heartburn symptom... nice! :upside-down_face:',
#   '51123724'],
#  ['1288113959573180418', 'help :face_with_rolling_eyes:', '51123724'],
#  ['1288113407267233792', 'vex ic', '51123724'],
#  ['1288111847468490753', 'bat**', '51123724'],
#  ['1288110821554323458', 'got be.', '51123724'],
#  ['1288110450459123717',
#   'gotta trolling... cause :woman_shrugging_medium_skin_tone:',
#   '51123724'],
#  ['1288100875332984832',
#   'rasshole mannnnnnn :face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth::face_with_symbols_on_mouth:',
#   '51123724'],
#  ['1288097636457820160', 'trash. ass. men. :unamused_face:', '51123724'],
#  ['1288097503993376768',
#   'rt "men trash" tweets ruffle feathers certain group men mean...',
#   '51123724'],
#  ['1288096613362270209',
#   'happy birthday :smiling_face_with_smiling_eyes::partying_face:',
#   '51123724'],
#  ['1288096415038820352',
#   'rt everyday mind 140mph thinking opportunities. access capital need address locally w',
#   '51123724'],
#  ['1288094759228186624',
#   'rt young people quarantine family, theyve come realise its time',
#   '51123724'],
#  ['1288094342331211781',
#   'foolishness :face_with_steam_from_nose:',
#   '51123724'],
#  ['1288081933105352706',
#   ':beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes::beaming_face_with_smiling_eyes:',
#   '51123724'],
#  ['1287956748700131329',
#   'rt amazing advice assess situation / behaviors/ patterns tell people ... u as',
#   '51123724'],
#  ['1287954516822953985',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287937457338679299', '', '51123724'],
#  ['1287932521515298817',
#   'rt mature women dont problem broke man, problem man comfortable broke.',
#   '51123724'],
#  ['1287922810741022722', '', '51123724'],
#  ['1287922250960830466', 'soon cuss you!', '51123724'],
#  ['1287921337449816064',
#   'owen blindddd bizzy! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing: crehnnnnn :loudly_crying_face:',
#   '51123724'],
#  ['1287920270968336384',
#   'rt nigga like gonna apply pressure. ifs. ands. buts.',
#   '51123724'],
#  ['1287920214336851969', 'know believe esaf too... ripowen!!', '51123724'],
#  ['1287919424490688513',
#   'owen mussie 2 drinks :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287917828075593729',
#   'shes laughing hes amused :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287917467713626112',
#   'rt baloo. serious. sure youre laughing. seriousness laughing matter. 14/10',
#   '51123724'],
#  ['1287915808337862656', 'cause dem miserable af...', '51123724'],
#  ['1287910925501112322',
#   'rt youre intelligent, exceptional, creative, talented etc... lean it. dont shy away it. dimming parts yourself',
#   '51123724'],
#  ['1287910917225709574',
#   'rt dumbing attract people terrible idea. end dating people cant enjoy intellectual conversatio',
#   '51123724'],
#  ['1287909778853965824',
#   'cause here!? searching ways blame woman assault...',
#   '51123724'],
#  ['1287908491680718850', 'ppl sick ic', '51123724'],
#  ['1287822701705531399', 'drugs drugs :slightly_frowning_face:', '51123724'],
#  ['1287821964350980096', 'slandering auntie whitney??', '51123724'],
#  ['1287793404139765760', 'its thing committed!', '51123724'],
#  ['1287787094023319560', 'thanks :folded_hands_medium_skin_tone:', '51123724'],
#  ['1287786754070720512', 'you... :unamused_face:', '51123724'],
#  ['1287781924665270273',
#   'rt job afford it, buy things improve ability work-from-home sta',
#   '51123724'],
#  ['1287777045657931776', ':upside-down_face:', '51123724'],
#  ['1287769697220526080',
#   '8701... eyeeee meannnn :confused_face::confused_face:',
#   '51123724'],
#  ['1287768708065230848',
#   'utter disrespect ya kno! dem couldnt referring usher raymond iv :woozy_face:',
#   '51123724'],
#  ['1287763299254317058',
#   ':raising_hands_medium_skin_tone::raising_hands_medium_skin_tone::raising_hands_medium_skin_tone::raising_hands_medium_skin_tone:',
#   '51123724'],
#  ['1287762921557315586',
#   'took tf owwwwttttttt :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287740829696581632', 'agreed tbh', '51123724'],
#  ['1287739833880903681', 'maam.', '51123724'],
#  ['1287739702829883392',
#   'thanks luv :face_blowing_a_kiss: pushing too!',
#   '51123724'],
#  ['1287709178165952512', 'amen :folded_hands_medium_skin_tone:', '51123724'],
#  ['1287708987950075904',
#   'rt rejection isnt bad thing. lead new better opportunities...',
#   '51123724'],
#  ['1287572291052883968', 'rt favorite tik tok', '51123724'],
#  ['1287569104874934272',
#   'rt let viral now! sizzla vs buju happen officialcampaign!! reggae!! dancehall!! greatness!! ver!!',
#   '51123724'],
#  ['1287567341673381890',
#   'rt connected song life. try jesus. me. cuz throw hands.',
#   '51123724'],
#  ['1287507684187615233',
#   "rt dad : we're getting dog dad : (bluenjy ig)",
#   '51123724'],
#  ['1287436203265073152',
#   'jesus christ! west indies killingggggggggg meeeeeeeeee',
#   '51123724'],
#  ['1287435647129706498',
#   'rt im getting close buy car outright auction, need reliable transportation',
#   '51123724'],
#  ['1287431833072869376',
#   'murdaaaaaa :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287431638071246848',
#   'tweet makes lotttt sense :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287409098795950080',
#   'rt pro athlete barbados = 1% chance getting loan, mortgage . incase people didnt know . cas',
#   '51123724'],
#  ['1287400407568912395', 'rt guys :pleading_face:', '51123724'],
#  ['1287394927694032897',
#   'rt act like im ok deep inside im tired spending damn money :broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart::broken_heart:',
#   '51123724'],
#  ['1287215830632206336',
#   'want bajan version indianmatchmaking!! :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287190798287675400',
#   'somebody sima auntie number dey fa me... wanna sain quick :pleading_face: indianmatchmaking!!',
#   '51123724'],
#  ['1287137857598038016',
#   ':rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287137507541430283', ':smiling_face_with_hearts:', '51123724'],
#  ['1287136984394272771',
#   'gaff olympic sport... bajans!! yc :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287113966242729984',
#   'rest fall out!? :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:',
#   '51123724'],
#  ['1287108999415042051', '', '51123724'],
#  ['1287099929207480326',
#   'loveeeeee :smiling_face_with_heart-eyes::smiling_face_with_hearts:',
#   '51123724'],
#  ['1287084531795873794', 'win... dont matter making.', '51123724'],
#  ...]

# %%
len(tweets_array)
# Out:
# 10000

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

from csv import writer


device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(device)
model = model.to(device)

out_file = 'user_embeddings3_sar.csv'

with open(out_file, 'a') as f:

#with open('user_embedding.csv', newline='', mode='a', encoding='utf-8') as f_object:

  # Pass this file object to csv.writer() and get a writer object
  #writer_object = writer(f_object)

  for row in tweets_array:

    #row[0] - tweet_id, row[1] - tweet, row[2] - user_id/label

    encoded_input = tokenizer(row[1], padding=True, truncation=True, return_tensors='pt').to(device)

    # Compute token embeddings
    with torch.no_grad():
      model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    embedding = torch.mean(torch.Tensor.cpu(sentence_embeddings), 0).numpy()
    
    writer = csv.writer(f)
    writer.writerow([row[0], np.array_str((1/i)*embedding, max_line_width=np.inf), row[2]])

    print('I', end='')
# Out:
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# cuda:0
# ...

# %%
df = pd.read_csv('user_embeddings3_sar.csv', header = None)

# %%
df
# Out:
#                           0  \
# 0       1331806220596834309
# 1       1328817876858515457
# 2       1327812984312360967
# 3       1326383107117899777
# 4       1326382157993046017
# ...                     ...
# 109995  1279588299619926023
# 109996  1276217789557157888
# 109997  1276194294395809792
# 109998  1276193567384514560
# 109999  1275233465500413952
#
#                                                         1                   2
# 0       [-2.76897754e-05 -1.10188114e-06  1.55866383e-...  707672778867130368
# 1       [-2.02395913e-05  2.61095153e-07  3.13298879e-...  707672778867130368
# 2       [-4.10710527e-05  2.09783120e-05 -2.04861635e-...  707672778867130368
# 3       [-1.12013768e-05  7.31568298e-06 -4.11455840e-...  707672778867130368
# 4       [-2.84063026e-05  1.90368264e-05  1.51708136e-...  707672778867130368
# ...                                                   ...                 ...
# 109995  [-6.63095605e-08  3.71013311e-06 -3.54425424e-...            18181081
# 109996  [-2.91709694e-06  5.58827367e-07  1.32699154e-...            18181081
# 109997  [ 8.63899913e-07 -1.00229981e-05 -1.43146860e-...            18181081
# 109998  [ 1.3221979e-06  6.3757789e-06 -3.6107190e-06 ...            18181081
# 109999  [-4.18372201e-06  7.15694114e-06  4.16877981e-...            18181081
#
# [110000 rows x 3 columns]

# %%
len(df.loc[0,1])
# Out:
# 6145

# %%
len(df.loc[109999,1])
# Out:
# 12289
